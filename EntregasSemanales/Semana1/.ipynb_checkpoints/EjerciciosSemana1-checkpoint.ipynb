# %% [markdown]
# # Ejercicios Semana 1 Teoría de Números y Criptografía

# %% [markdown]
# ## Ejercicio 1
#
# Dado tu número n=26504975.
#
# **1- Mientras sea múltiplo de 2,3,5,7 u 11 le sumas uno. De forma que tu nuevo n no tenga esos divisores primos.**

# %%
n=26504975
# Out:
# 26504975

# %%
primos = [2,3,5,7,11]
no_es_multiplo = true

while no_es_multiplo
    no_es_multiplo = false
        for p in primos
            if mod(n,p) == 0
                n += 1
                no_es_multiplo = true
            end
        end
end

print("El valor del n que no es múltiplo de $primos es n = $n")
# Out:
# El valor del n que no es múltiplo de [2, 3, 5, 7, 11] es n = 26504977

# %% [markdown]
# **2- Calcula $a^{n-1}$ mod n, para cada uno de esas 5 bases usando sucesivamente el algoritmo de izda-dcha y de dcha a izda.**
#
# En primer lugar usaremos el algoritmo de exponenciación rápida de derecha a izquierda para calcular $a^{n-1}$.

# %%
function exponenciacion_rapida_dcha_izda(a, b, print=false)
    base=a
    acu=1
    num=b
    num_binario= string(num-1; base=2)
    contador=0
    
    println("Numero en binario=$num_binario")
    
    if print==true
        println("Iteración: $contador")
        println("acu: $acu")
        println("base: $base")
        println("")
    end
    
    for i in reverse(num_binario) 
        if i!='0'
            acu=mod(acu*base,num)
        end
        
        base=mod(base*base,num)

        contador+=1
        
        if print==true
            println("Iteración: $contador")
            println("acu: $acu")
            println("base: $base")
            println("")
        end
    end
    
    println("El resultado es $acu")
end
# Out:
# exponenciacion_rapida_dcha_izda (generic function with 2 methods)

# %% [markdown]
# Vamos a probar con el ejemplo de la ayuda.

# %%
exponenciacion_rapida_dcha_izda(2,27213647,true)
# Out:
# Numero en binario=1100111110011111101001110
# Iteración: 0
# acu: 1
# base: 2
#
# Iteración: 1
# acu: 1
# base: 4
#
# Iteración: 2
# acu: 4
# base: 16
#
# Iteración: 3
# acu: 64
# base: 256
#
# Iteración: 4
# acu: 16384
# base: 65536
#
# Iteración: 5
# acu: 16384
# base: 22424717
#
# Iteración: 6
# acu: 16384
# base: 12167649
#
# Iteración: 7
# acu: 14796941
# base: 26585339
#
# Iteración: 8
# acu: 14796941
# base: 9779482
#
# Iteración: 9
# acu: 120175
# base: 15067521
#
# Iteración: 10
# acu: 24905736
# base: 12424177
#
# Iteración: 11
# acu: 9320126
# base: 14159809
#
# Iteración: 12
# acu: 10785431
# base: 15283
#
# Iteración: 13
# acu: 682094
# base: 15860913
#
# Iteración: 14
# acu: 11508854
# base: 2314287
#
# Iteración: 15
# acu: 11508854
# base: 6452299
#
# Iteración: 16
# acu: 11508854
# base: 17649979
#
# Iteración: 17
# acu: 15616437
# base: 11515927
#
# Iteración: 18
# acu: 8921297
# base: 9800221
#
# Iteración: 19
# acu: 10593740
# base: 23701151
#
# Iteración: 20
# acu: 1995822
# base: 21932449
#
# Iteración: 21
# acu: 4173990
# base: 3214080
#
# Iteración: 22
# acu: 4173990
# base: 9845200
#
# Iteración: 23
# acu: 4173990
# base: 760573
#
# Iteración: 24
# acu: 16105485
# base: 18007697
#
# Iteración: 25
# acu: 1
# base: 13932984
#
# El resultado es 1

# %% [markdown]
# Como podemos ver da el mismo resultado del ejemplo en cada iteración. Vamos a realizar ahora el apartado 2.

# %%
for i in primos
    println("Probamos con la base $i")
    exponenciacion_rapida_dcha_izda(i,n,false) 
end
# Out:
# Probamos con la base 2
# Numero en binario=1100101000110111100010000
# El resultado es 19574020
# Probamos con la base 3
# Numero en binario=1100101000110111100010000
# El resultado es 12215788
# Probamos con la base 5
# Numero en binario=1100101000110111100010000
# El resultado es 5558275
# Probamos con la base 7
# Numero en binario=1100101000110111100010000
# El resultado es 14115151
# Probamos con la base 11
# Numero en binario=1100101000110111100010000
# El resultado es 4065986

# %% [markdown]
# Ahora realizamos los mismos experimentos con la exponenciación rápida de izquierda a derecha.

# %%
function exponenciacion_rapida_izda_dcha(a,b)
    base=a
    acu=1
    num=b
    num_binario= string(num-1; base=2)
    contador=0
    
    if print==true
        println("Iteración: $contador")
        println("acu: $acu")
        println("base: $base")
        println("")
    end
    
    println(num_binario)
    for i in num_binario*"0"
        println("Iteración: $contador")
        println("acu: $acu")
        println("")
        
        if i!='0'
            acu=mod(acu*acu*base,num)
        else
            acu=mod(acu*acu,num)
        end
        contador+=1
        
        
    end
    
end
# Out:
# exponenciacion_rapida_izda_dcha (generic function with 1 method)

# %%
exponenciacion_rapida_izda_dcha(2,27213647)
# Out:
# 1100111110011111101001110
# Iteración: 0
# acu: 1
#
# Iteración: 1
# acu: 2
#
# Iteración: 2
# acu: 8
#
# Iteración: 3
# acu: 64
#
# Iteración: 4
# acu: 4096
#
# Iteración: 5
# acu: 6340785
#
# Iteración: 6
# acu: 6967674
#
# Iteración: 7
# acu: 2913255
#
# Iteración: 8
# acu: 5278505
#
# Iteración: 9
# acu: 8390032
#
# Iteración: 10
# acu: 21530122
#
# Iteración: 11
# acu: 20718507
#
# Iteración: 12
# acu: 6234754
#
# Iteración: 13
# acu: 14354021
#
# Iteración: 14
# acu: 18664779
#
# Iteración: 15
# acu: 21238793
#
# Iteración: 16
# acu: 9159785
#
# Iteración: 17
# acu: 1897988
#
# Iteración: 18
# acu: 6353813
#
# Iteración: 19
# acu: 22747524
#
# Iteración: 20
# acu: 12082479
#
# Iteración: 21
# acu: 22922644
#
# Iteración: 22
# acu: 15226206
#
# Iteración: 23
# acu: 8424067
#
# Iteración: 24
# acu: 1
#
# Iteración: 25
# acu: 1

# %%
for i in primos
    println("Probamos con la base $i")
    exponenciacion_rapida_izda_dcha(i,n) 
end
# Out:
# Probamos con la base 2
# 1100101000110111100010000
# Iteración: 0
# acu: 1
#
# Iteración: 1
# acu: 2
#
# Iteración: 2
# acu: 8
#
# Iteración: 3
# acu: 64
#
# Iteración: 4
# acu: 4096
#
# Iteración: 5
# acu: 7049455
#
# Iteración: 6
# acu: 24805254
#
# Iteración: 7
# acu: 5062481
#
# Iteración: 8
# acu: 17919958
#
# Iteración: 9
# acu: 2656599
#
# Iteración: 10
# acu: 11516034
#
# Iteración: 11
# acu: 16821704
#
# Iteración: 12
# acu: 13552717
#
# Iteración: 13
# acu: 13604168
#
# Iteración: 14
# acu: 25748565
#
# Iteración: 15
# acu: 18855467
#
# Iteración: 16
# acu: 10549331
#
# Iteración: 17
# acu: 5508680
#
# Iteración: 18
# acu: 7175100
#
# Iteración: 19
# acu: 11914142
#
# Iteración: 20
# acu: 11392112
#
# Iteración: 21
# acu: 1407650
#
# Iteración: 22
# acu: 19451934
#
# Iteración: 23
# acu: 62008
#
# Iteración: 24
# acu: 1770399
#
# Iteración: 25
# acu: 19574020
#
# Probamos con la base 3
# 1100101000110111100010000
# Iteración: 0
# acu: 1
#
# Iteración: 1
# acu: 3
#
# Iteración: 2
# acu: 27
#
# Iteración: 3
# acu: 729
#
# Iteración: 4
# acu: 531441
#
# Iteración: 5
# acu: 4009684
#
# Iteración: 6
# acu: 17801334
#
# Iteración: 7
# acu: 11392005
#
# Iteración: 8
# acu: 1261190
#
# Iteración: 9
# acu: 10041353
#
# Iteración: 10
# acu: 20845921
#
# Iteración: 11
# acu: 7398371
#
# Iteración: 12
# acu: 18094019
#
# Iteración: 13
# acu: 18911857
#
# Iteración: 14
# acu: 23056784
#
# Iteración: 15
# acu: 24908871
#
# Iteración: 16
# acu: 5981712
#
# Iteración: 17
# acu: 22980624
#
# Iteración: 18
# acu: 10192122
#
# Iteración: 19
# acu: 11310381
#
# Iteración: 20
# acu: 10668304
#
# Iteración: 21
# acu: 9806122
#
# Iteración: 22
# acu: 25132838
#
# Iteración: 23
# acu: 10899103
#
# Iteración: 24
# acu: 16206377
#
# Iteración: 25
# acu: 12215788
#
# Probamos con la base 5
# 1100101000110111100010000
# Iteración: 0
# acu: 1
#
# Iteración: 1
# acu: 5
#
# Iteración: 2
# acu: 125
#
# Iteración: 3
# acu: 15625
#
# Iteración: 4
# acu: 5595832
#
# Iteración: 5
# acu: 3888661
#
# Iteración: 6
# acu: 11884927
#
# Iteración: 7
# acu: 739705
#
# Iteración: 8
# acu: 21246814
#
# Iteración: 9
# acu: 8951674
#
# Iteración: 10
# acu: 23448130
#
# Iteración: 11
# acu: 25720203
#
# Iteración: 12
# acu: 2927520
#
# Iteración: 13
# acu: 15542427
#
# Iteración: 14
# acu: 17229566
#
# Iteración: 15
# acu: 11176325
#
# Iteración: 16
# acu: 10769637
#
# Iteración: 17
# acu: 7455809
#
# Iteración: 18
# acu: 14047542
#
# Iteración: 19
# acu: 12750122
#
# Iteración: 20
# acu: 11588061
#
# Iteración: 21
# acu: 7392406
#
# Iteración: 22
# acu: 22949960
#
# Iteración: 23
# acu: 16232172
#
# Iteración: 24
# acu: 2463353
#
# Iteración: 25
# acu: 5558275
#
# Probamos con la base 7
# 1100101000110111100010000
# Iteración: 0
# acu: 1
#
# Iteración: 1
# acu: 7
#
# Iteración: 2
# acu: 343
#
# Iteración: 3
# acu: 117649
#
# Iteración: 4
# acu: 5689207
#
# Iteración: 5
# acu: 7690267
#
# Iteración: 6
# acu: 22420867
#
# Iteración: 7
# acu: 9774254
#
# Iteración: 8
# acu: 17879004
#
# Iteración: 9
# acu: 14769606
#
# Iteración: 10
# acu: 26194813
#
# Iteración: 11
# acu: 26502610
#
# Iteración: 12
# acu: 12713846
#
# Iteración: 13
# acu: 5638320
#
# Iteración: 14
# acu: 25798719
#
# Iteración: 15
# acu: 22402807
#
# Iteración: 16
# acu: 5959912
#
# Iteración: 17
# acu: 5472783
#
# Iteración: 18
# acu: 14120710
#
# Iteración: 19
# acu: 400938
#
# Iteración: 20
# acu: 25099316
#
# Iteración: 21
# acu: 8265606
#
# Iteración: 22
# acu: 6642910
#
# Iteración: 23
# acu: 11040892
#
# Iteración: 24
# acu: 3511919
#
# Iteración: 25
# acu: 14115151
#
# Probamos con la base 11
# 1100101000110111100010000
# Iteración: 0
# acu: 1
#
# Iteración: 1
# acu: 11
#
# Iteración: 2
# acu: 1331
#
# Iteración: 3
# acu: 1771561
#
# Iteración: 4
# acu: 555128
#
# Iteración: 5
# acu: 10531786
#
# Iteración: 6
# acu: 11510610
#
# Iteración: 7
# acu: 10294643
#
# Iteración: 8
# acu: 1052535
#
# Iteración: 9
# acu: 1402556
#
# Iteración: 10
# acu: 16950150
#
# Iteración: 11
# acu: 3916734
#
# Iteración: 12
# acu: 18003071
#
# Iteración: 13
# acu: 20231711
#
# Iteración: 14
# acu: 19026793
#
# Iteración: 15
# acu: 20329773
#
# Iteración: 16
# acu: 3453016
#
# Iteración: 17
# acu: 1906395
#
# Iteración: 18
# acu: 5954762
#
# Iteración: 19
# acu: 10591757
#
# Iteración: 20
# acu: 6132148
#
# Iteración: 21
# acu: 19170024
#
# Iteración: 22
# acu: 10374104
#
# Iteración: 23
# acu: 5963074
#
# Iteración: 24
# acu: 22545540
#
# Iteración: 25
# acu: 4065986

# %% [markdown]
# **3- ¿Es un Posible primo de Fermat para alguna de ellas? ¿Es n un pseudoprimo para alguna de ellas?**
#
# Como podemos ver el número n no es primo, pues para toda base probada $a^{n-1}$ mod n era distinto de 1. Por lo tanto no puede ser un posible primo de Fermat ni un pseudoprimo para ninguna base.

# %% [markdown]
# ### Ejercicio 2
#
# Dado tu número n=26505013 de ocho cifras de la lista publicada.
#
# **1- Usa el algoritmo Manual para calcular el símbolo de Jacobi $(\frac{p}{n})$, para $p$ cada uno de los 5 primeros primos.**

# %% [markdown]
# En primer lugar vamos a programar el algoritmo para poder comprobar que son correctos los resultados obtenidos a mano:

# %%
function simbolo_jacobi(a,n)
    t=1
    m=abs(n)
    b=mod(a,m)
    
    while a != 0
        while mod(a,2)==0
            a=a/2
            if mod(m,8)==3 || mod(m,8)==5
                t=-t
            end
        end
        aux=a
        a=m
        m=aux
        if mod(a,4)==mod(m,4)==3
            t=-t
        end 
        
        a=mod(a,m)
        
    end
        
    if m==1
        return t
    else 
        return 0
    end
        
    
end
# Out:
# simbolo_jacobi (generic function with 1 method)

# %% [markdown]
# Una vez programado el Algoritmo vamos a proceder a calcular a mano el símbolo de Jacobi para nuestro n con los cinco primeros primos:
#
# - Para $p=2$:
#
#     Como  $n \equiv 5$ mod 8 tenemos que $(\frac{2}{n})=-1$ aplicando la primera propiedad del símbolo de Jacobi.
#
# - Para $p=3$:
#
#     En este caso tanto $n$ como $p$ son impares, luego deben ser congruentes a 1 o a 3 módulo 4.
#
#     Como $n \equiv 1$ mod 4 $\Rightarrow$ $(\frac{3}{n})=(\frac{n}{3})$
#
#     Por otro lado como $n \equiv 1$ mod 3 $\Rightarrow$ $(\frac{3}{n})=(\frac{1}{3})=1$ ( ya que $2^2 \equiv 1$ mod 3).
#
# - Para $p=5$:
#
#     Como son ambos impares, al ser $5 \equiv 1$ mod 4 se tiene que $(\frac{5}{n})=(\frac{n}{5})$.
#
#     Del mismo modo como $n \equiv 3$ mod 5 se tiene que $(\frac{n}{5})=(\frac{3}{5})$.
#
#     Como  $5 \equiv 1$ mod 4 $(\frac{3}{5})=(\frac{5}{3})$ y como $5 \equiv 2$ mod 3 se tiene que $(\frac{5}{3})=(\frac{2}{3})$.
#
#     Finalmente como $3\equiv 3$ mod 8 se tiene que $(\frac{2}{3})=-1$ por las primeras propiedades del símbolo de Jacobi.
#
# - Para $p=7$:
#
#     Ambos son impares y como $n \equiv 1$ mod 4 $(\frac{7}{n})=(\frac{n}{7})$, por otro lado $n \equiv 3$ mod 7, luego $(\frac{n}{7})=(\frac{3}{7})$.
#
#     En este caso ambos números son congruentes con 3 módulo 4, luego las propiedades del símbolo de Jacobi nos dicen que $(\frac{3}{7})=-(\frac{7}{3})=-(\frac{1}{3})=(-1)(1)=-1$. Pues ya habíamos calculado antes el símbolo de Jacobi de $\frac{1}{3}$.
#
# - Para $p=11$:
#
#     Como $n \equiv 1$ mod 4 $\Rightarrow$ $(\frac{11}{n})=(\frac{n}{11})$, a su vez $(\frac{n}{11})=(\frac{7}{11})$ pues $n \equiv 7$mod 11.
#     Como tanto 7 como 11 son congruentes con 3 módulo 4 se tiene que $(\frac{7}{11})=-(\frac{11}{7})=-(\frac{4}{7})=-1$ pues $2^2 \equiv 4$ mod 11.

# %% [markdown]
# Finalmente comprobemos que con el algoritmo implementado se obtienen los mismos resultados:

# %%
for i in primos 
    s=simbolo_jacobi(i,26505013)
    println("simbolo de Jacobi obtenido para $i / 26505013 = $s")
end
# Out:
# simbolo de Jacobi obtenido para 2 / 26505013 = -1
# simbolo de Jacobi obtenido para 3 / 26505013 = 1
# simbolo de Jacobi obtenido para 5 / 26505013 = -1
# simbolo de Jacobi obtenido para 7 / 26505013 = -1
# simbolo de Jacobi obtenido para 11 / 26505013 = -1

# %% [markdown]
# Como podemos apreciar los resultados coinciden.

# %% [markdown]
# **2- Si para alguna de esas bases tu número sale posible primo de Fermat, comprueba si además es posible primo de Euler.**
#
# Vamos a utilizar el algoritmo de exponenciación rápida de izquierda a derecha implementado en el ejercicio anterior:

# %%
for i in primos
    println("Probamos con la base $i")
    exponenciacion_rapida_izda_dcha(i,26505013) 
end
# Out:
# Probamos con la base 2
# 1100101000110111100110100
# Iteración: 0
# acu: 1
#
# Iteración: 1
# acu: 2
#
# Iteración: 2
# acu: 8
#
# Iteración: 3
# acu: 64
#
# Iteración: 4
# acu: 4096
#
# Iteración: 5
# acu: 7049419
#
# Iteración: 6
# acu: 6353835
#
# Iteración: 7
# acu: 5272446
#
# Iteración: 8
# acu: 17148412
#
# Iteración: 9
# acu: 3849240
#
# Iteración: 10
# acu: 1745431
#
# Iteración: 11
# acu: 6848043
#
# Iteración: 12
# acu: 4717534
#
# Iteración: 13
# acu: 7340615
#
# Iteración: 14
# acu: 6823515
#
# Iteración: 15
# acu: 15617238
#
# Iteración: 16
# acu: 626276
#
# Iteración: 17
# acu: 891604
#
# Iteración: 18
# acu: 19342920
#
# Iteración: 19
# acu: 401541
#
# Iteración: 20
# acu: 10361204
#
# Iteración: 21
# acu: 17365171
#
# Iteración: 22
# acu: 14152448
#
# Iteración: 23
# acu: 1799882
#
# Iteración: 24
# acu: 26505012
#
# Iteración: 25
# acu: 1
#
# Probamos con la base 3
# 1100101000110111100110100
# Iteración: 0
# acu: 1
#
# Iteración: 1
# acu: 3
#
# Iteración: 2
# acu: 27
#
# Iteración: 3
# acu: 729
#
# Iteración: 4
# acu: 531441
#
# Iteración: 5
# acu: 2858872
#
# Iteración: 6
# acu: 10293678
#
# Iteración: 7
# acu: 1986699
#
# Iteración: 8
# acu: 5410719
#
# Iteración: 9
# acu: 6532928
#
# Iteración: 10
# acu: 7675207
#
# Iteración: 11
# acu: 19003980
#
# Iteración: 12
# acu: 2041105
#
# Iteración: 13
# acu: 25172672
#
# Iteración: 14
# acu: 10408883
#
# Iteración: 15
# acu: 9832325
#
# Iteración: 16
# acu: 2337937
#
# Iteración: 17
# acu: 18360210
#
# Iteración: 18
# acu: 9171889
#
# Iteración: 19
# acu: 2702972
#
# Iteración: 20
# acu: 11428080
#
# Iteración: 21
# acu: 24675301
#
# Iteración: 22
# acu: 24315927
#
# Iteración: 23
# acu: 1
#
# Iteración: 24
# acu: 1
#
# Iteración: 25
# acu: 1
#
# Probamos con la base 5
# 1100101000110111100110100
# Iteración: 0
# acu: 1
#
# Iteración: 1
# acu: 5
#
# Iteración: 2
# acu: 125
#
# Iteración: 3
# acu: 15625
#
# Iteración: 4
# acu: 5595508
#
# Iteración: 5
# acu: 2732445
#
# Iteración: 6
# acu: 5556029
#
# Iteración: 7
# acu: 12920993
#
# Iteración: 8
# acu: 4790531
#
# Iteración: 9
# acu: 7291002
#
# Iteración: 10
# acu: 17546087
#
# Iteración: 11
# acu: 9654692
#
# Iteración: 12
# acu: 20251722
#
# Iteración: 13
# acu: 7501391
#
# Iteración: 14
# acu: 16997637
#
# Iteración: 15
# acu: 20717016
#
# Iteración: 16
# acu: 20553555
#
# Iteración: 17
# acu: 631369
#
# Iteración: 18
# acu: 17923654
#
# Iteración: 19
# acu: 23013578
#
# Iteración: 20
# acu: 8466494
#
# Iteración: 21
# acu: 5685839
#
# Iteración: 22
# acu: 17667535
#
# Iteración: 23
# acu: 24705131
#
# Iteración: 24
# acu: 26505012
#
# Iteración: 25
# acu: 1
#
# Probamos con la base 7
# 1100101000110111100110100
# Iteración: 0
# acu: 1
#
# Iteración: 1
# acu: 7
#
# Iteración: 2
# acu: 343
#
# Iteración: 3
# acu: 117649
#
# Iteración: 4
# acu: 5670415
#
# Iteración: 5
# acu: 1017188
#
# Iteración: 6
# acu: 21739876
#
# Iteración: 7
# acu: 1857762
#
# Iteración: 8
# acu: 8895888
#
# Iteración: 9
# acu: 10844054
#
# Iteración: 10
# acu: 14723453
#
# Iteración: 11
# acu: 5783686
#
# Iteración: 12
# acu: 7138348
#
# Iteración: 13
# acu: 18656552
#
# Iteración: 14
# acu: 5083281
#
# Iteración: 15
# acu: 6848801
#
# Iteración: 16
# acu: 15219987
#
# Iteración: 17
# acu: 19816138
#
# Iteración: 18
# acu: 3711339
#
# Iteración: 19
# acu: 18037133
#
# Iteración: 20
# acu: 21885146
#
# Iteración: 21
# acu: 12646047
#
# Iteración: 22
# acu: 2938499
#
# Iteración: 23
# acu: 24705131
#
# Iteración: 24
# acu: 26505012
#
# Iteración: 25
# acu: 1
#
# Probamos con la base 11
# 1100101000110111100110100
# Iteración: 0
# acu: 1
#
# Iteración: 1
# acu: 11
#
# Iteración: 2
# acu: 1331
#
# Iteración: 3
# acu: 1771561
#
# Iteración: 4
# acu: 22797417
#
# Iteración: 5
# acu: 23337442
#
# Iteración: 6
# acu: 6863878
#
# Iteración: 7
# acu: 17174366
#
# Iteración: 8
# acu: 10247535
#
# Iteración: 9
# acu: 13240667
#
# Iteración: 10
# acu: 1022442
#
# Iteración: 11
# acu: 11176928
#
# Iteración: 12
# acu: 7594851
#
# Iteración: 13
# acu: 15130847
#
# Iteración: 14
# acu: 20249437
#
# Iteración: 15
# acu: 10908101
#
# Iteración: 16
# acu: 17980661
#
# Iteración: 17
# acu: 21933607
#
# Iteración: 18
# acu: 7842051
#
# Iteración: 19
# acu: 11068598
#
# Iteración: 20
# acu: 3594148
#
# Iteración: 21
# acu: 24950228
#
# Iteración: 22
# acu: 19695586
#
# Iteración: 23
# acu: 24705131
#
# Iteración: 24
# acu: 26505012
#
# Iteración: 25
# acu: 1

# %% [markdown]
# Como podemos ver, tras las 25 iteraciones nuestro número sale posible primo de Fermat para cada base escogida, veamos ahora si es posible primo de Euler.
#
# Para ver si es posible primo de Euler debemos comprobar el test de  SOLOVAY-STRASSEN de manera que si se cumple lo siguiente:
#
# $$(\frac{a}{n}) \equiv a^{(n-1)/2} \; mod \; n$$
#
# Se dirá que n es un posible primo de Euler para a, y en caso contrario se tendrá que n es compuesto.
#
# Por un lado la parte izquierda de la equivalencia la hemos calculado ya, veamos la parte derecha.
#
# De nuevo nos ayudaremos del algoritmo de exponenciación rápida al que le haremos unas modificaciones pues ahora el exponente no coincide con el valor del módulo, por otro lado, en lugar de transformar a binario de forma manual el exponente vamos a utilzar las operaciones lógicas a nivel de bit de Julia para ahorrarnos estas transformaciones, así pues usaremos el and a nivel de bits "&" con 1 para identificar si el valor actual del exponente es par (devuelve 0) o impar (devuelve 1) y en cada iteración desplazaremos a la derecha el valor del exponente a nivel de bits, esto es, por ejemplo en la iteración i-ésima el valor en binario del exponente es 1101, en la iteración siguiente será 110.
#
# De esta forma el algoritmo quedaría de la siguiente manera:

# %%
function exponenciacion_rapida_modificado(base,exp,m)
    acu=1
    
    while exp>0 
        if (exp&1)>0 
            acu=mod(acu*base,m)
        end
        
        exp>>=1
        base=mod(base*base,m)
        
    end
    
    println(acu)
end
# Out:
# exponenciacion_rapida_modificado (generic function with 1 method)

# %% [markdown]
# A continuación probamos el algoritmo con los valores del ejercicio

# %%
m=13252506
n=26505013
println("El exponente es: $m")

for i in primos
    println("Probamos con la base $i")
    exponenciacion_rapida_modificado(i,m,n) 
end
# Out:
# El exponente es: 13252506
# Probamos con la base 2
# 26505012
# Probamos con la base 3
# 1
# Probamos con la base 5
# 26505012
# Probamos con la base 7
# 26505012
# Probamos con la base 11
# 26505012

# %% [markdown]
# Como podemos observar coinciden con el valor del símbolo de Jacobi para cada primo, luego podemos decir que el número n es un posible primo de Euler para 2,3,5,7 y 11.

# %% [markdown]
# **3- ¿Es tu número n pseudoprimo de Fermat o de Euler para alguna de las bases?**
#
# En nuestro caso sería un pseudoprimo de Euler y de Fermat para todas las bases probadas, lo que nos permite concluir que nuestro n sería primo con cierta probabilidad.
